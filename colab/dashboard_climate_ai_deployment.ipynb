# %% [markdown]
# <a href="https://colab.research.google.com/github/alfanugraha/climate-risk-adaptation/blob/main/dashboard_climate_ai_deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install library

# %%
# !pip install rsconnect-python

# %% [markdown]
# # 2. Download Apps

# %%
# !gdown 1cPApt2ZlnXHJySLUahyIi-d25V-3hnUl

# %%
# !unzip shiny-dashboard.zip -d shiny-dashboard

# %% [markdown]
# # 3. Konfigurasi

# %% [markdown]
# `!rsconnect add --account [ACCOUNT] --name [NAME] --token [TOKEN] --secret [SECRET]`

# %% [markdown]
# # 4. Deployment

# %% [markdown]
# `!rsconnect deploy shiny path/to/your/app --name 9op952-alfadsai --title your-app-name`
